# %% [markdown]
# # Alexa Dandridge Irrigation Kaggle Notebook

# %% [markdown]
# # **Homework 2: Bagging and Boosting**

# %% [markdown]
# ### 4. Find and upvote 3-4 Notebooks

# %% [markdown]
# The first discussion that I found useful is from <https://www.kaggle.com/competitions/playground-series-s6e4/discussion/686709>. This discussion elaborates and shares resources about the metric specific to this competition: balanced accuracy. This helps me improve my approach because it helps me understand the end goal better.

# %% [markdown]
# Another discussion that was useful to me is from <https://www.kaggle.com/competitions/playground-series-s6e4/discussion/691609>. This source is useful because it mentions the importance of focusing on threshold-based feature engineering and understanding the data before overinvesting in modeling.

# %% [markdown]
# The final discussion post that may be useful is from <https://www.kaggle.com/competitions/playground-series-s6e4/discussion/687460>. It describes the exact formula for seperating the data into 3 classes (low, medium, high) to achieve a strong balanced accuracy. It is helpful to consider implementing into my modeling.

# %% [markdown]
# ### 5. Initial EDA/Modeling Notebook

# %% [markdown]
# ***Notebook for this Homework Assignment***:<https://github.com/alexadandridge/AdvancedMachineLearning/blob/master/IrrigationKaggle/KaggleCompetitionEDA.ipynb>
# Note: This includes ONE notebook with EDA, boosting, bagging models included.
#
# **What insights did you gain?**
#
# One thing that jumped out to me after doing initial EDA and using SweetViz was the imbalance for the target variable. Most of the irrigation_need in the training data is low or medium, with very little measured as high. There are no missing data values.
#
# **Is there a feature you think is especially important?**
#
# I believe that strong features may be: soil_moisture or rainfall because they seem to relate to irrigation (water). Other factors like sunlight or soil_type may also be important because it has to do with environmental influences.
#
# **Any potential issues?**
#
# It may be challenging to find a model that easily performs well with the imbalanced data
#
# **Did you try anything new that you learned from Kaggle or other sources?**
#
# I used techniques, such as looking at the shape or info, from python code on the dataset. This was taught to me in a previous machine learning course.

# %% [markdown]
# ### 7. Review

# %% [markdown]
# I have provided links to the resources with elaboration and my EDA notebook above.
#
# For my modeling approaches, I used Random Forest classifier for my bagging model and XGBoost for a boosting model. I used stratified cross validation and reviewed balanced accuracy for the competition's evaluation metric.
#
# For random forest, I tried tuning the hyperparameters quite a bit at first, but my cell was taking a very long time to run. I stopped running that cell, and changed the hyperparameters to lower the time, and that worked!
#
# For XGBoost, I tuned six features (I only tuned four in the random forest model), whcih seemed to create a strong model. The XGBoost model captures the relationships between features better because the balanced accuracy score improved from 0.89 (random forest) to 0.96 (XGBoost). This showed me that boosting may be a better strategy for this dataset.
#
# Leaderboard ranking:
#
# 1753 for XGBoost Model;
# 1920 for Random Forest Model
#
# For my work, boosting was stronger than bagging. Bagging provided a strong baseline, but boosting's iterative learning process proved impactful in this case. Both models were simple to perform evaluation on.

# %% [markdown]
# ### 8. Phase 2 Plans

# %% [markdown]
# My next plan to improve the model performance is to play with more tuning of hyperparameters. I know with XGBoost, extreme tuning may not be very beneficial. So, I also want to consider feature enginnering. I may consider strategies to handle the class imbalance in the training data. For instance, I can add weights to each class to see if that changes the performance of the model.
